# %%
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division
import os

import tensorflow as tf
from six.moves import range, zip
import numpy as np
import zhusuan as zs

# %%
def standardize_data(X_train, X_test, X_valid):
    X_mean = np.mean(X_train, axis=0)
    X_std = np.std(X_train, axis=0)

    X_train -= X_mean
    X_train /= X_std
    X_test -= X_mean
    X_test /= X_std
    X_valid -= X_mean
    X_valid /= X_std

    return X_train, X_test, X_valid

def standardize_data_with_std(y_train, y_test):
    y_mean = np.mean(y_train, axis=0)
    y_std = np.std(y_train, axis=0)

    y_train -= y_mean
    y_train /= y_std
    y_test -= y_mean
    y_test /= y_std
    
    return y_train, y_test, y_mean, y_std

# %%
@zs.meta_bayesian_net(scope="bnn", reuse_variables=True)
def build_bnn(x, layer_sizes, n_particles):
    bn = zs.BayesianNet()
    h = tf.tile(x[None, ...], [n_particles, 1, 1])
    for i, (n_in, n_out) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        w = bn.normal("w" + str(i), tf.zeros([n_out, n_in + 1]), std=1.,
                      group_ndims=2, n_samples=n_particles)
        h = tf.concat([h, tf.ones(tf.shape(h)[:-1])[..., None]], -1)
        h = tf.einsum("imk,ijk->ijm", w, h) / tf.sqrt(
            tf.cast(tf.shape(h)[2], tf.float32))
        if i < len(layer_sizes) - 2:
            h = tf.nn.relu(h)

    y_mean = bn.deterministic("y_mean", tf.squeeze(h, 2))
    y_logstd = tf.get_variable("y_logstd", shape=[],
                               initializer=tf.constant_initializer(0.))
    bn.normal("y", y_mean, logstd=y_logstd)
    return bn

# %%
@zs.reuse_variables(scope="variational")
def build_mean_field_variational(layer_sizes, n_particles):
    bn = zs.BayesianNet()
    for i, (n_in, n_out) in enumerate(zip(layer_sizes[:-1], layer_sizes[1:])):
        w_mean = tf.get_variable(
            "w_mean_" + str(i), shape=[n_out, n_in + 1],
            initializer=tf.constant_initializer(0.))
        w_logstd = tf.get_variable(
            "w_logstd_" + str(i), shape=[n_out, n_in + 1],
            initializer=tf.constant_initializer(0.))
        bn.normal("w" + str(i), w_mean, logstd=w_logstd,
                  n_samples=n_particles, group_ndims=2)
    return bn
# Out:
# WARNING:tensorflow:From C:\Users\AP84590\Documents\VBNNHTc\zhusuan\framework\utils.py:106: The name tf.make_template is deprecated. Please use tf.compat.v1.make_template instead.

# %%
def main():
    tf.set_random_seed(10)
    np.random.seed(90)

    #Data loading
    dataset = tf.data.experimental.CsvDataset(
    "High_Tc_train.csv",
    [tf.float32,  # Required field, use dtype or empty tensor
     tf.constant([0.0], dtype=tf.float32),  # Optional field, default to 0.0
     tf.int32,  # Required field, use dtype or empty tensor
     ],
    )
    
    dataset_size = tf.size(dataset)
    
    #Divide into features and labels
    dataset_size = tf.size(dataset)
    train_size = int(0.7 * dataset_size)
    test_size = int(0.3 * dataset_size)

    dataset = dataset.shuffle()
    train_dataset = full_dataset.take(train_size)
    test_dataset = full_dataset.skip(train_size)       

    
    x_train = train_dataset.iloc[:,:-1]
    y_train = train_dataset.iloc[:,:-1]
    x_test = test_dataset.iloc[:,:-1]
    y_test = test_dataset.iloc[:,:-1]
    
    
    n_train, x_dim = x_train.shape

    # Standardize data
    x_train, x_test, _, _ = dataset.standardize(x_train, x_test)
    y_train, y_test, mean_y_train, std_y_train = dataset.standardize(
        y_train, y_test)

    # Define model parameters
    n_hiddens = [100]

    # Build the computation graph
    n_particles = tf.placeholder(tf.int32, shape=[], name="n_particles")
    x = tf.placeholder(tf.float32, shape=[None, x_dim])
    y = tf.placeholder(tf.float32, shape=[None])
    layer_sizes = [x_dim] + n_hiddens + [1]
    w_names = ["w" + str(i) for i in range(len(layer_sizes) - 1)]

    model = build_bnn(x, layer_sizes, n_particles)
    variational = build_mean_field_variational(layer_sizes, n_particles)

    def log_joint(bn):
        log_pws = bn.cond_log_prob(w_names)
        log_py_xw = bn.cond_log_prob('y')
        return tf.add_n(log_pws) + tf.reduce_mean(log_py_xw, 1) * n_train

    model.log_joint = log_joint

    lower_bound = zs.variational.elbo(
        model, {'y': y}, variational=variational, axis=0)
    cost = lower_bound.sgvb()

    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    infer_op = optimizer.minimize(cost)

    # prediction: rmse & log likelihood
    y_mean = lower_bound.bn["y_mean"]
    y_pred = tf.reduce_mean(y_mean, 0)
    rmse = tf.sqrt(tf.reduce_mean((y_pred - y) ** 2)) * std_y_train
    
    total_error = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))
    unexplained_error = tf.reduce_sum(tf.square(tf.subtract(y, y_pred)))
    r_squared = tf.subtract(tf.div(total_error, unexplained_error),1.0)
    
    log_py_xw = lower_bound.bn.cond_log_prob("y")
    log_likelihood = tf.reduce_mean(zs.log_mean_exp(log_py_xw, 0)) - tf.log(
        std_y_train)

    # Define training/evaluation parameters
    lb_samples = 100
    ll_samples = 10000
    epochs = 1000
    batch_size = 10
    iters = (n_train-1) // batch_size + 1
    test_freq = 10

    # Run the inference
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch in range(1, epochs + 1):
            perm = np.random.permutation(x_train.shape[0])
            x_train = x_train[perm, :]
            y_train = y_train[perm]
            lbs = []
            for t in range(iters):
                x_batch = x_train[t * batch_size:(t + 1) * batch_size]
                y_batch = y_train[t * batch_size:(t + 1) * batch_size]
                _, lb = sess.run(
                    [infer_op, lower_bound],
                    feed_dict={n_particles: lb_samples,
                               x: x_batch, y: y_batch})
                lbs.append(lb)
            print('Epoch {}: Lower bound = {}'.format(epoch, np.mean(lbs)))

            if epoch % test_freq == 0:
                test_rmse, test_ll, test_r = sess.run(
                    [rmse, log_likelihood, r_squared],
                    feed_dict={n_particles: ll_samples,
                               x: x_test, y: y_test})
                print('>> TEST')
                print('>> Test rmse = {}, log_likelihood = {}, r_squared = {}'
                      .format(test_rmse, test_ll, test_r))

# %%
if __name__ == "__main__":
    main()
# Out:
# WARNING:tensorflow:From C:\Users\AP84590\Documents\VBNNHTc\zhusuan\distributions\base.py:258: The name tf.assert_rank is deprecated. Please use tf.compat.v1.assert_rank instead.
#
# WARNING:tensorflow:From C:\Users\AP84590\Documents\VBNNHTc\zhusuan\distributions\univariate.py:167: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:From C:\Users\AP84590\Documents\VBNNHTc\zhusuan\distributions\univariate.py:100: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From <ipython-input-4-c11db43bb42f>:61: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1: Lower bound = -725.4192504882812
# Epoch 2: Lower bound = -697.8917236328125
# Epoch 3: Lower bound = -653.2720947265625
# Epoch 4: Lower bound = -592.192626953125
# Epoch 5: Lower bound = -554.4517822265625
# Epoch 6: Lower bound = -544.1273193359375
# Epoch 7: Lower bound = -546.5131225585938
# Epoch 8: Lower bound = -533.01953125
# Epoch 9: Lower bound = -533.8604736328125
# Epoch 10: Lower bound = -526.9624633789062
# >> TEST
# >> Test rmse = 5.130523204803467, log_likelihood = -3.022861957550049, r_squared = -1.6757659912109375
# Epoch 11: Lower bound = -538.0867309570312
# Epoch 12: Lower bound = -527.0652465820312
# Epoch 13: Lower bound = -523.5552978515625
# Epoch 14: Lower bound = -524.8297119140625
# Epoch 15: Lower bound = -520.8697509765625
# Epoch 16: Lower bound = -524.641845703125
# Epoch 17: Lower bound = -521.964599609375
# Epoch 18: Lower bound = -516.8428344726562
# Epoch 19: Lower bound = -519.8618774414062
# Epoch 20: Lower bound = -521.3434448242188
# >> TEST
# >> Test rmse = 5.311086654663086, log_likelihood = -3.029961585998535, r_squared = -1.8979551792144775
# Epoch 21: Lower bound = -521.1412353515625
# Epoch 22: Lower bound = -516.0440063476562
# Epoch 23: Lower bound = -520.8904418945312
# Epoch 24: Lower bound = -520.7578735351562
# Epoch 25: Lower bound = -517.10888671875
# Epoch 26: Lower bound = -515.3507690429688
# Epoch 27: Lower bound = -514.7893676757812
# Epoch 28: Lower bound = -516.7600708007812
# Epoch 29: Lower bound = -510.87823486328125
# Epoch 30: Lower bound = -512.4987182617188
# >> TEST
# >> Test rmse = 5.489654541015625, log_likelihood = -3.0491089820861816, r_squared = -2.096480131149292
# Epoch 31: Lower bound = -509.5018310546875
# Epoch 32: Lower bound = -511.125732421875
# Epoch 33: Lower bound = -509.9972839355469
# Epoch 34: Lower bound = -507.6230773925781
# Epoch 35: Lower bound = -512.0977172851562
# Epoch 36: Lower bound = -507.69586181640625
# Epoch 37: Lower bound = -510.70758056640625
# Epoch 38: Lower bound = -506.989990234375
# Epoch 39: Lower bound = -504.5220642089844
# Epoch 40: Lower bound = -503.6210021972656
# >> TEST
# >> Test rmse = 5.448303699493408, log_likelihood = -3.023831367492676, r_squared = -2.052239179611206
# Epoch 41: Lower bound = -505.4878845214844
# Epoch 42: Lower bound = -506.5361633300781
# Epoch 43: Lower bound = -501.36590576171875
# Epoch 44: Lower bound = -503.7821044921875
# Epoch 45: Lower bound = -500.0463562011719
# Epoch 46: Lower bound = -497.7430419921875
# Epoch 47: Lower bound = -501.3459167480469
# Epoch 48: Lower bound = -501.9424133300781
# Epoch 49: Lower bound = -496.70074462890625
# Epoch 50: Lower bound = -503.36102294921875
# >> TEST
# >> Test rmse = 5.470702648162842, log_likelihood = -3.022012233734131, r_squared = -2.0763278007507324
# Epoch 51: Lower bound = -495.6534118652344
# Epoch 52: Lower bound = -498.1367492675781
# Epoch 53: Lower bound = -494.7774353027344
# Epoch 54: Lower bound = -503.06964111328125
# Epoch 55: Lower bound = -509.0006408691406
# Epoch 56: Lower bound = -507.3290100097656
# Epoch 57: Lower bound = -499.21893310546875
# Epoch 58: Lower bound = -498.64093017578125
# Epoch 59: Lower bound = -495.9473876953125
# Epoch 60: Lower bound = -495.718017578125
# >> TEST
# >> Test rmse = 5.421533584594727, log_likelihood = -3.017465591430664, r_squared = -2.023056745529175
# Epoch 61: Lower bound = -495.88311767578125
# Epoch 62: Lower bound = -496.0540466308594
# Epoch 63: Lower bound = -497.48321533203125
# Epoch 64: Lower bound = -494.2188720703125
# Epoch 65: Lower bound = -504.70538330078125
# Epoch 66: Lower bound = -497.80206298828125
# Epoch 67: Lower bound = -493.5226745605469
# Epoch 68: Lower bound = -498.6288757324219
# Epoch 69: Lower bound = -491.95343017578125
# Epoch 70: Lower bound = -494.65545654296875
# >> TEST
# >> Test rmse = 5.55914831161499, log_likelihood = -3.0280520915985107, r_squared = -2.16861891746521
# Epoch 71: Lower bound = -494.83624267578125
# Epoch 72: Lower bound = -494.96710205078125
# Epoch 73: Lower bound = -493.0308532714844
# Epoch 74: Lower bound = -496.85906982421875
# Epoch 75: Lower bound = -493.2109069824219
# Epoch 76: Lower bound = -497.5701904296875
# Epoch 77: Lower bound = -498.1690368652344
# Epoch 78: Lower bound = -493.2516174316406
# Epoch 79: Lower bound = -496.9347839355469
# Epoch 80: Lower bound = -493.1377258300781
# >> TEST
# >> Test rmse = 5.4492082595825195, log_likelihood = -3.011179208755493, r_squared = -2.053217649459839
# Epoch 81: Lower bound = -491.4942321777344
# Epoch 82: Lower bound = -493.4366149902344
# Epoch 83: Lower bound = -494.1328430175781
# Epoch 84: Lower bound = -498.3209533691406
# Epoch 85: Lower bound = -494.6250915527344
# Epoch 86: Lower bound = -490.2679748535156
# Epoch 87: Lower bound = -493.6181945800781
# Epoch 88: Lower bound = -499.12554931640625
# Epoch 89: Lower bound = -492.5796813964844
# Epoch 90: Lower bound = -501.8129577636719
# >> TEST
# >> Test rmse = 5.395461559295654, log_likelihood = -3.0092461109161377, r_squared = -1.9942171573638916
# Epoch 91: Lower bound = -493.3163757324219
# Epoch 92: Lower bound = -489.77703857421875
# Epoch 93: Lower bound = -492.6470642089844
# Epoch 94: Lower bound = -493.7113952636719
# Epoch 95: Lower bound = -490.1642761230469
# Epoch 96: Lower bound = -492.2832336425781
# Epoch 97: Lower bound = -491.8207092285156
# Epoch 98: Lower bound = -491.23492431640625
# Epoch 99: Lower bound = -486.7657165527344
# Epoch 100: Lower bound = -486.89129638671875
# >> TEST
# >> Test rmse = 5.297582149505615, log_likelihood = -2.9855194091796875, r_squared = -1.8821191787719727
# Epoch 101: Lower bound = -487.8334655761719
# Epoch 102: Lower bound = -485.4809265136719
# Epoch 103: Lower bound = -490.38018798828125
# Epoch 104: Lower bound = -486.7353515625
# Epoch 105: Lower bound = -486.43402099609375
# Epoch 106: Lower bound = -488.5487365722656
# Epoch 107: Lower bound = -495.0111389160156
# Epoch 108: Lower bound = -494.2723693847656
# Epoch 109: Lower bound = -484.2377624511719
# Epoch 110: Lower bound = -487.90838623046875
# >> TEST
# >> Test rmse = 5.155937194824219, log_likelihood = -2.956456184387207, r_squared = -1.70845627784729
# Epoch 111: Lower bound = -492.87890625
# Epoch 112: Lower bound = -478.7828063964844
# Epoch 113: Lower bound = -485.9871826171875
# Epoch 114: Lower bound = -496.4604187011719
# Epoch 115: Lower bound = -483.7289123535156
# Epoch 116: Lower bound = -482.4248352050781
# Epoch 117: Lower bound = -480.0777893066406
# Epoch 118: Lower bound = -481.3207702636719
# Epoch 119: Lower bound = -489.438720703125
# Epoch 120: Lower bound = -478.4986267089844
# >> TEST
# >> Test rmse = 5.069258689880371, log_likelihood = -2.9617695808410645, r_squared = -1.594930648803711
# Epoch 121: Lower bound = -481.7123718261719
# Epoch 122: Lower bound = -487.682861328125
# Epoch 123: Lower bound = -483.8057861328125
# Epoch 124: Lower bound = -480.2597961425781
# Epoch 125: Lower bound = -475.9092102050781
# Epoch 126: Lower bound = -478.91033935546875
# Epoch 127: Lower bound = -483.658447265625
# Epoch 128: Lower bound = -477.5205993652344
# Epoch 129: Lower bound = -481.8078308105469
# Epoch 130: Lower bound = -489.114501953125
# >> TEST
# >> Test rmse = 4.901948928833008, log_likelihood = -2.9304559230804443, r_squared = -1.358525276184082
# Epoch 131: Lower bound = -472.9832763671875
# Epoch 132: Lower bound = -475.1326904296875
# Epoch 133: Lower bound = -476.9102478027344
# Epoch 134: Lower bound = -474.08282470703125
# Epoch 135: Lower bound = -479.7198181152344
# Epoch 136: Lower bound = -474.4599609375
# Epoch 137: Lower bound = -476.53680419921875
# Epoch 138: Lower bound = -471.478271484375
# Epoch 139: Lower bound = -473.8524475097656
# Epoch 140: Lower bound = -483.237548828125
# >> TEST
# >> Test rmse = 4.786281108856201, log_likelihood = -2.9032163619995117, r_squared = -1.1803951263427734
# Epoch 141: Lower bound = -473.9273986816406
# Epoch 142: Lower bound = -467.49945068359375
# Epoch 143: Lower bound = -474.6827392578125
# Epoch 144: Lower bound = -472.995849609375
# Epoch 145: Lower bound = -469.80596923828125
# Epoch 146: Lower bound = -469.29327392578125
# Epoch 147: Lower bound = -471.953125
# Epoch 148: Lower bound = -471.98309326171875
# Epoch 149: Lower bound = -471.3066711425781
# Epoch 150: Lower bound = -467.8601379394531
# >> TEST
# >> Test rmse = 4.543425559997559, log_likelihood = -2.8733348846435547, r_squared = -0.7611498832702637
# Epoch 151: Lower bound = -475.7891540527344
# Epoch 152: Lower bound = -480.5811767578125
# Epoch 153: Lower bound = -465.5335388183594
# Epoch 154: Lower bound = -475.64898681640625
# Epoch 155: Lower bound = -469.3809509277344
# Epoch 156: Lower bound = -466.1527404785156
# Epoch 157: Lower bound = -468.9713439941406
# Epoch 158: Lower bound = -466.30255126953125
# Epoch 159: Lower bound = -467.42498779296875
# Epoch 160: Lower bound = -465.1912841796875
# >> TEST
# >> Test rmse = 4.426066875457764, log_likelihood = -2.8461711406707764, r_squared = -0.5333805084228516
# Epoch 161: Lower bound = -461.902587890625
# Epoch 162: Lower bound = -470.979736328125
# Epoch 163: Lower bound = -462.8343200683594
# Epoch 164: Lower bound = -464.52679443359375
# Epoch 165: Lower bound = -465.44696044921875
# Epoch 166: Lower bound = -466.72808837890625
# Epoch 167: Lower bound = -460.3420104980469
# Epoch 168: Lower bound = -465.17645263671875
# Epoch 169: Lower bound = -463.32733154296875
# Epoch 170: Lower bound = -476.89178466796875
# >> TEST
# >> Test rmse = 4.40886926651001, log_likelihood = -2.8293561935424805, r_squared = -0.49846744537353516
# Epoch 171: Lower bound = -470.09918212890625
# Epoch 172: Lower bound = -462.47344970703125
# Epoch 173: Lower bound = -467.7751770019531
# Epoch 174: Lower bound = -465.3017578125
# Epoch 175: Lower bound = -460.99151611328125
# Epoch 176: Lower bound = -457.0363464355469
# Epoch 177: Lower bound = -463.496826171875
# Epoch 178: Lower bound = -460.03680419921875
# Epoch 179: Lower bound = -469.65777587890625
# Epoch 180: Lower bound = -461.944580078125
# >> TEST
# >> Test rmse = 4.279396057128906, log_likelihood = -2.8189563751220703, r_squared = -0.22195863723754883
# Epoch 181: Lower bound = -462.564697265625
# Epoch 182: Lower bound = -462.8882141113281
# Epoch 183: Lower bound = -457.393798828125
# Epoch 184: Lower bound = -460.125
# Epoch 185: Lower bound = -460.78448486328125
# Epoch 186: Lower bound = -459.004638671875
# Epoch 187: Lower bound = -466.5028991699219
# Epoch 188: Lower bound = -460.88360595703125
# Epoch 189: Lower bound = -466.1753845214844
# Epoch 190: Lower bound = -459.27227783203125
# >> TEST
# >> Test rmse = 4.318139553070068, log_likelihood = -2.8181991577148438, r_squared = -0.3073134422302246
# Epoch 191: Lower bound = -460.4227600097656
# Epoch 192: Lower bound = -466.6302185058594
# Epoch 193: Lower bound = -461.171875
# Epoch 194: Lower bound = -462.460693359375
# Epoch 195: Lower bound = -458.96246337890625
# Epoch 196: Lower bound = -467.0043029785156
# Epoch 197: Lower bound = -461.1504821777344
# Epoch 198: Lower bound = -461.31903076171875
# Epoch 199: Lower bound = -461.3805236816406
# Epoch 200: Lower bound = -462.295654296875
# >> TEST
# >> Test rmse = 4.181976318359375, log_likelihood = -2.8004493713378906, r_squared = 0.0032439231872558594
# Epoch 201: Lower bound = -459.9398498535156
# Epoch 202: Lower bound = -455.5814514160156
# Epoch 203: Lower bound = -461.6831970214844
# Epoch 204: Lower bound = -467.2471008300781
# Epoch 205: Lower bound = -457.6126403808594
# Epoch 206: Lower bound = -458.86395263671875
# Epoch 207: Lower bound = -465.628173828125
# Epoch 208: Lower bound = -464.1120910644531
# Epoch 209: Lower bound = -465.29132080078125
# Epoch 210: Lower bound = -460.9593200683594
# >> TEST
# >> Test rmse = 4.095242023468018, log_likelihood = -2.786479949951172, r_squared = 0.21741962432861328
# Epoch 211: Lower bound = -462.663818359375
# Epoch 212: Lower bound = -462.98553466796875
# Epoch 213: Lower bound = -464.6534118652344
# Epoch 214: Lower bound = -462.7137756347656
# Epoch 215: Lower bound = -460.25335693359375
# Epoch 216: Lower bound = -461.2386779785156
# Epoch 217: Lower bound = -461.24749755859375
# Epoch 218: Lower bound = -463.5286560058594
# Epoch 219: Lower bound = -459.88604736328125
# Epoch 220: Lower bound = -461.1092529296875
# >> TEST
# >> Test rmse = 4.009857177734375, log_likelihood = -2.770794153213501, r_squared = 0.44198131561279297
# Epoch 221: Lower bound = -460.6954040527344
# Epoch 222: Lower bound = -466.7756042480469
# Epoch 223: Lower bound = -462.52313232421875
# Epoch 224: Lower bound = -466.73760986328125
# Epoch 225: Lower bound = -464.6888732910156
# Epoch 226: Lower bound = -460.2514953613281
# Epoch 227: Lower bound = -459.00555419921875
# Epoch 228: Lower bound = -459.6177673339844
# Epoch 229: Lower bound = -458.4350891113281
# Epoch 230: Lower bound = -461.116943359375
# >> TEST
# >> Test rmse = 3.9903154373168945, log_likelihood = -2.7698733806610107, r_squared = 0.49541330337524414
# Epoch 231: Lower bound = -465.5796813964844
# Epoch 232: Lower bound = -464.6854553222656
# Epoch 233: Lower bound = -455.8298645019531
# Epoch 234: Lower bound = -459.61187744140625
# Epoch 235: Lower bound = -462.3222961425781
# Epoch 236: Lower bound = -463.08245849609375
# Epoch 237: Lower bound = -458.7040100097656
# Epoch 238: Lower bound = -457.263671875
# Epoch 239: Lower bound = -459.99468994140625
# Epoch 240: Lower bound = -461.66949462890625
# >> TEST
# >> Test rmse = 4.062368869781494, log_likelihood = -2.7783193588256836, r_squared = 0.3022003173828125
# Epoch 241: Lower bound = -457.451416015625
# Epoch 242: Lower bound = -457.3840026855469
# Epoch 243: Lower bound = -465.8271789550781
# Epoch 244: Lower bound = -463.5346374511719
# Epoch 245: Lower bound = -457.4876403808594
# Epoch 246: Lower bound = -463.9858093261719
# Epoch 247: Lower bound = -463.1681823730469
# Epoch 248: Lower bound = -460.5848693847656
# Epoch 249: Lower bound = -461.1123352050781
# Epoch 250: Lower bound = -457.63018798828125
# >> TEST
# >> Test rmse = 4.067075729370117, log_likelihood = -2.777559757232666, r_squared = 0.2899355888366699
# Epoch 251: Lower bound = -458.6805725097656
# Epoch 252: Lower bound = -460.4483642578125
# Epoch 253: Lower bound = -463.79180908203125
# Epoch 254: Lower bound = -457.8999328613281
# Epoch 255: Lower bound = -463.1247863769531
# Epoch 256: Lower bound = -459.428955078125
# Epoch 257: Lower bound = -461.0204772949219
# Epoch 258: Lower bound = -458.45184326171875
# Epoch 259: Lower bound = -462.3370056152344
# Epoch 260: Lower bound = -460.77325439453125
# >> TEST
# >> Test rmse = 3.9713375568389893, log_likelihood = -2.761157989501953, r_squared = 0.5480613708496094
# Epoch 261: Lower bound = -460.5907287597656
# Epoch 262: Lower bound = -461.1684265136719
# Epoch 263: Lower bound = -460.4374084472656
# Epoch 264: Lower bound = -461.0402526855469
# Epoch 265: Lower bound = -461.79473876953125
# Epoch 266: Lower bound = -460.064453125
# Epoch 267: Lower bound = -458.590087890625
# Epoch 268: Lower bound = -470.6844787597656
# Epoch 269: Lower bound = -461.56976318359375
# Epoch 270: Lower bound = -457.7520751953125
# >> TEST
# >> Test rmse = 3.9625136852264404, log_likelihood = -2.7608847618103027, r_squared = 0.5727982521057129
# Epoch 271: Lower bound = -469.2740173339844
# Epoch 272: Lower bound = -459.44256591796875
# Epoch 273: Lower bound = -459.9268493652344
# Epoch 274: Lower bound = -461.5122985839844
# Epoch 275: Lower bound = -459.0732421875
# Epoch 276: Lower bound = -460.54144287109375
# Epoch 277: Lower bound = -461.6488952636719
# Epoch 278: Lower bound = -465.60186767578125
# Epoch 279: Lower bound = -458.2353210449219
# Epoch 280: Lower bound = -460.3432312011719
# >> TEST
# >> Test rmse = 3.8735828399658203, log_likelihood = -2.7482943534851074, r_squared = 0.8316202163696289
# Epoch 281: Lower bound = -459.45758056640625
# Epoch 282: Lower bound = -457.5901794433594
# Epoch 283: Lower bound = -462.0668029785156
# Epoch 284: Lower bound = -466.7247009277344
# Epoch 285: Lower bound = -461.54718017578125
# Epoch 286: Lower bound = -461.04644775390625
# Epoch 287: Lower bound = -458.21319580078125
# Epoch 288: Lower bound = -460.0410461425781
# Epoch 289: Lower bound = -457.9539794921875
# Epoch 290: Lower bound = -458.2725830078125
# >> TEST
# >> Test rmse = 3.920166254043579, log_likelihood = -2.7528133392333984, r_squared = 0.6938486099243164
# Epoch 291: Lower bound = -461.2083435058594
# Epoch 292: Lower bound = -457.7524719238281
# Epoch 293: Lower bound = -458.2931823730469
# Epoch 294: Lower bound = -457.51727294921875
# Epoch 295: Lower bound = -459.35296630859375
# Epoch 296: Lower bound = -460.389404296875
# Epoch 297: Lower bound = -459.087890625
# Epoch 298: Lower bound = -463.639404296875
# Epoch 299: Lower bound = -460.33184814453125
# Epoch 300: Lower bound = -465.447265625
# >> TEST
# >> Test rmse = 3.8978304862976074, log_likelihood = -2.7530899047851562, r_squared = 0.7592902183532715
# Epoch 301: Lower bound = -461.4994812011719
# Epoch 302: Lower bound = -456.76971435546875
# Epoch 303: Lower bound = -460.1501770019531
# Epoch 304: Lower bound = -462.47088623046875
# Epoch 305: Lower bound = -459.5576171875
# Epoch 306: Lower bound = -464.6168518066406
# Epoch 307: Lower bound = -463.954833984375
# Epoch 308: Lower bound = -459.998046875
# Epoch 309: Lower bound = -459.6117248535156
# Epoch 310: Lower bound = -458.5074157714844
# >> TEST
# >> Test rmse = 3.913048028945923, log_likelihood = -2.7475810050964355, r_squared = 0.7145824432373047
# Epoch 311: Lower bound = -459.2787780761719
# Epoch 312: Lower bound = -460.0830078125
# Epoch 313: Lower bound = -464.3716735839844
# Epoch 314: Lower bound = -463.9704895019531
# Epoch 315: Lower bound = -458.4926452636719
# Epoch 316: Lower bound = -460.8245544433594
# Epoch 317: Lower bound = -464.4440002441406
# Epoch 318: Lower bound = -463.74359130859375
# Epoch 319: Lower bound = -462.99639892578125
# Epoch 320: Lower bound = -462.2800598144531
# >> TEST
# >> Test rmse = 3.931683301925659, log_likelihood = -2.7644972801208496, r_squared = 0.6605386734008789
# Epoch 321: Lower bound = -458.0506896972656
# Epoch 322: Lower bound = -459.7281188964844
# Epoch 323: Lower bound = -465.1584167480469
# Epoch 324: Lower bound = -459.353759765625
# Epoch 325: Lower bound = -464.0712890625
# Epoch 326: Lower bound = -462.1854248046875
# Epoch 327: Lower bound = -462.41632080078125
# Epoch 328: Lower bound = -468.213134765625
# Epoch 329: Lower bound = -462.8086242675781
# Epoch 330: Lower bound = -465.0968017578125
# >> TEST
# >> Test rmse = 4.017669677734375, log_likelihood = -2.768976926803589, r_squared = 0.4208383560180664
# Epoch 331: Lower bound = -464.106201171875
# Epoch 332: Lower bound = -461.6788330078125
# Epoch 333: Lower bound = -462.89984130859375
# Epoch 334: Lower bound = -459.296630859375
# Epoch 335: Lower bound = -459.8589172363281
# Epoch 336: Lower bound = -473.5971374511719
# Epoch 337: Lower bound = -465.4178466796875
# Epoch 338: Lower bound = -459.9766540527344
# Epoch 339: Lower bound = -457.9850158691406
# Epoch 340: Lower bound = -462.919677734375
# >> TEST
# >> Test rmse = 3.897780179977417, log_likelihood = -2.749678134918213, r_squared = 0.7594389915466309
# Epoch 341: Lower bound = -455.39508056640625
# Epoch 342: Lower bound = -457.6676330566406
# Epoch 343: Lower bound = -463.59649658203125
# Epoch 344: Lower bound = -461.0623779296875
# Epoch 345: Lower bound = -458.23687744140625
# Epoch 346: Lower bound = -461.1222839355469
# Epoch 347: Lower bound = -472.6769714355469
# Epoch 348: Lower bound = -459.5296325683594
# Epoch 349: Lower bound = -460.015380859375
# Epoch 350: Lower bound = -457.1856384277344
# >> TEST
# >> Test rmse = 3.851594924926758, log_likelihood = -2.7441158294677734, r_squared = 0.8983917236328125
# Epoch 351: Lower bound = -466.6241455078125
# Epoch 352: Lower bound = -458.8901672363281
# Epoch 353: Lower bound = -464.04339599609375
# Epoch 354: Lower bound = -465.0086975097656
# Epoch 355: Lower bound = -459.0967712402344
# Epoch 356: Lower bound = -454.9414978027344
# Epoch 357: Lower bound = -457.06280517578125
# Epoch 358: Lower bound = -459.9363098144531
# Epoch 359: Lower bound = -461.3231201171875
# Epoch 360: Lower bound = -462.2476501464844
# >> TEST
# >> Test rmse = 3.9641823768615723, log_likelihood = -2.753422737121582, r_squared = 0.5681076049804688
# Epoch 361: Lower bound = -459.0436096191406
# Epoch 362: Lower bound = -457.74249267578125
# Epoch 363: Lower bound = -459.745361328125
# Epoch 364: Lower bound = -458.3429870605469
# Epoch 365: Lower bound = -459.6397705078125
# Epoch 366: Lower bound = -464.5101013183594
# Epoch 367: Lower bound = -457.69561767578125
# Epoch 368: Lower bound = -459.0341491699219
# Epoch 369: Lower bound = -460.339599609375
# Epoch 370: Lower bound = -460.7531433105469
# >> TEST
# >> Test rmse = 3.896158218383789, log_likelihood = -2.748019218444824, r_squared = 0.7642350196838379
# Epoch 371: Lower bound = -459.9838562011719
# Epoch 372: Lower bound = -465.79534912109375
# Epoch 373: Lower bound = -464.181396484375
# Epoch 374: Lower bound = -462.93707275390625
# Epoch 375: Lower bound = -459.82940673828125
# Epoch 376: Lower bound = -460.31524658203125
# Epoch 377: Lower bound = -459.337890625
# Epoch 378: Lower bound = -458.35546875
# Epoch 379: Lower bound = -461.13726806640625
# Epoch 380: Lower bound = -460.266357421875
# >> TEST
# >> Test rmse = 3.894686698913574, log_likelihood = -2.750478744506836, r_squared = 0.7685914039611816
# Epoch 381: Lower bound = -461.878662109375
# Epoch 382: Lower bound = -469.21466064453125
# Epoch 383: Lower bound = -458.42694091796875
# Epoch 384: Lower bound = -460.7392883300781
# Epoch 385: Lower bound = -460.1478576660156
# Epoch 386: Lower bound = -458.15313720703125
# Epoch 387: Lower bound = -462.4368591308594
# Epoch 388: Lower bound = -458.8407287597656
# Epoch 389: Lower bound = -458.51287841796875
# Epoch 390: Lower bound = -462.712646484375
# >> TEST
# >> Test rmse = 3.8524229526519775, log_likelihood = -2.7413618564605713, r_squared = 0.8958563804626465
# Epoch 391: Lower bound = -458.89569091796875
# Epoch 392: Lower bound = -462.21734619140625
# Epoch 393: Lower bound = -459.9935607910156
# Epoch 394: Lower bound = -461.18731689453125
# Epoch 395: Lower bound = -459.06768798828125
# Epoch 396: Lower bound = -462.0835876464844
# Epoch 397: Lower bound = -459.03436279296875
# Epoch 398: Lower bound = -460.24456787109375
# Epoch 399: Lower bound = -460.1560363769531
# Epoch 400: Lower bound = -457.4184265136719
# >> TEST
# >> Test rmse = 3.9083340167999268, log_likelihood = -2.7521286010742188, r_squared = 0.7283763885498047
# Epoch 401: Lower bound = -459.58526611328125
# Epoch 402: Lower bound = -461.5760803222656
# Epoch 403: Lower bound = -469.8930358886719
# Epoch 404: Lower bound = -473.2298278808594
# Epoch 405: Lower bound = -462.86651611328125
# Epoch 406: Lower bound = -462.0068664550781
# Epoch 407: Lower bound = -459.2655029296875
# Epoch 408: Lower bound = -457.9551696777344
# Epoch 409: Lower bound = -458.6209716796875
# Epoch 410: Lower bound = -463.4590759277344
# >> TEST
# >> Test rmse = 3.890261173248291, log_likelihood = -2.7465498447418213, r_squared = 0.7817234992980957
# Epoch 411: Lower bound = -460.548828125
# Epoch 412: Lower bound = -460.70391845703125
# Epoch 413: Lower bound = -461.5231018066406
# Epoch 414: Lower bound = -460.44219970703125
# Epoch 415: Lower bound = -461.2269592285156
# Epoch 416: Lower bound = -460.2368469238281
# Epoch 417: Lower bound = -462.0003967285156
# Epoch 418: Lower bound = -460.95770263671875
# Epoch 419: Lower bound = -458.9247741699219
# Epoch 420: Lower bound = -461.83673095703125
# >> TEST
# >> Test rmse = 3.8584227561950684, log_likelihood = -2.7461869716644287, r_squared = 0.877535343170166
# Epoch 421: Lower bound = -461.7655029296875
# Epoch 422: Lower bound = -460.5615539550781
# Epoch 423: Lower bound = -458.8648376464844
# Epoch 424: Lower bound = -458.19219970703125
# Epoch 425: Lower bound = -460.1376037597656
# Epoch 426: Lower bound = -457.7088623046875
# Epoch 427: Lower bound = -460.0697937011719
# Epoch 428: Lower bound = -459.83709716796875
# Epoch 429: Lower bound = -459.366455078125
# Epoch 430: Lower bound = -461.36053466796875
# >> TEST
# >> Test rmse = 3.9672231674194336, log_likelihood = -2.7546844482421875, r_squared = 0.559575080871582
# Epoch 431: Lower bound = -457.75250244140625
# Epoch 432: Lower bound = -458.81683349609375
# Epoch 433: Lower bound = -460.2958068847656
# Epoch 434: Lower bound = -461.46173095703125
# Epoch 435: Lower bound = -460.2797546386719
# Epoch 436: Lower bound = -461.1791076660156
# Epoch 437: Lower bound = -465.05511474609375
# Epoch 438: Lower bound = -463.65191650390625
# Epoch 439: Lower bound = -461.147216796875
# Epoch 440: Lower bound = -475.72784423828125
# >> TEST
# >> Test rmse = 3.9857189655303955, log_likelihood = -2.7551639080047607, r_squared = 0.5080962181091309
# Epoch 441: Lower bound = -461.6631164550781
# Epoch 442: Lower bound = -465.19891357421875
# Epoch 443: Lower bound = -457.3375549316406
# Epoch 444: Lower bound = -460.6043701171875
# Epoch 445: Lower bound = -462.529052734375
# Epoch 446: Lower bound = -460.5952453613281
# Epoch 447: Lower bound = -457.7446594238281
# Epoch 448: Lower bound = -461.0580749511719
# Epoch 449: Lower bound = -461.85113525390625
# Epoch 450: Lower bound = -457.7628173828125
# >> TEST
# >> Test rmse = 3.876331090927124, log_likelihood = -2.747105121612549, r_squared = 0.8233532905578613
# Epoch 451: Lower bound = -462.0819396972656
# Epoch 452: Lower bound = -456.166748046875
# Epoch 453: Lower bound = -463.56121826171875
# Epoch 454: Lower bound = -457.9732360839844
# Epoch 455: Lower bound = -457.84136962890625
# Epoch 456: Lower bound = -459.4914245605469
# Epoch 457: Lower bound = -459.9031982421875
# Epoch 458: Lower bound = -458.8521423339844
# Epoch 459: Lower bound = -458.7283020019531
# Epoch 460: Lower bound = -461.0372009277344
# >> TEST
# >> Test rmse = 3.8856680393218994, log_likelihood = -2.7493724822998047, r_squared = 0.7954006195068359
# Epoch 461: Lower bound = -458.2504577636719
# Epoch 462: Lower bound = -469.8564147949219
# Epoch 463: Lower bound = -464.6244201660156
# Epoch 464: Lower bound = -464.73590087890625
# Epoch 465: Lower bound = -462.3145446777344
# Epoch 466: Lower bound = -458.78485107421875
# Epoch 467: Lower bound = -457.87860107421875
# Epoch 468: Lower bound = -461.8392639160156
# Epoch 469: Lower bound = -460.18585205078125
# Epoch 470: Lower bound = -459.3211975097656
# >> TEST
# >> Test rmse = 3.9447951316833496, log_likelihood = -2.7568423748016357, r_squared = 0.6229729652404785
# Epoch 471: Lower bound = -456.6685485839844
# Epoch 472: Lower bound = -457.2177429199219
# Epoch 473: Lower bound = -463.5741882324219
# Epoch 474: Lower bound = -463.1722717285156
# Epoch 475: Lower bound = -461.20550537109375
# Epoch 476: Lower bound = -459.9130859375
# Epoch 477: Lower bound = -465.3415832519531
# Epoch 478: Lower bound = -462.567138671875
# Epoch 479: Lower bound = -466.1922912597656
# Epoch 480: Lower bound = -461.29949951171875
# >> TEST
# >> Test rmse = 3.983752965927124, log_likelihood = -2.7701425552368164, r_squared = 0.5135340690612793
# Epoch 481: Lower bound = -457.9999694824219
# Epoch 482: Lower bound = -473.40496826171875
# Epoch 483: Lower bound = -468.9546203613281
# Epoch 484: Lower bound = -459.9546813964844
# Epoch 485: Lower bound = -457.7490539550781
# Epoch 486: Lower bound = -465.61737060546875
# Epoch 487: Lower bound = -459.7133483886719
# Epoch 488: Lower bound = -456.9375
# Epoch 489: Lower bound = -456.6706848144531
# Epoch 490: Lower bound = -457.843994140625
# >> TEST
# >> Test rmse = 3.8872649669647217, log_likelihood = -2.745090961456299, r_squared = 0.7906403541564941
# Epoch 491: Lower bound = -458.8713073730469
# Epoch 492: Lower bound = -459.656005859375
# Epoch 493: Lower bound = -456.7563781738281
# Epoch 494: Lower bound = -457.50457763671875
# Epoch 495: Lower bound = -465.92132568359375
# Epoch 496: Lower bound = -460.85113525390625
# Epoch 497: Lower bound = -458.80218505859375
# Epoch 498: Lower bound = -459.13995361328125
# Epoch 499: Lower bound = -465.2339782714844
# Epoch 500: Lower bound = -462.3449401855469
# >> TEST
# >> Test rmse = 3.8922133445739746, log_likelihood = -2.7543435096740723, r_squared = 0.7759261131286621
# Epoch 501: Lower bound = -467.0307312011719
# Epoch 502: Lower bound = -455.3397521972656
# Epoch 503: Lower bound = -458.5318298339844
# Epoch 504: Lower bound = -460.6623229980469
# Epoch 505: Lower bound = -456.4678039550781
# Epoch 506: Lower bound = -460.22869873046875
# Epoch 507: Lower bound = -464.569091796875
# Epoch 508: Lower bound = -461.07086181640625
# Epoch 509: Lower bound = -460.1637268066406
# Epoch 510: Lower bound = -458.8599548339844
# >> TEST
# >> Test rmse = 3.8811490535736084, log_likelihood = -2.750088930130005, r_squared = 0.8089041709899902
# Epoch 511: Lower bound = -463.8124694824219
# Epoch 512: Lower bound = -464.18707275390625
# Epoch 513: Lower bound = -466.65789794921875
# Epoch 514: Lower bound = -463.4361877441406
# Epoch 515: Lower bound = -457.4914245605469
# Epoch 516: Lower bound = -458.224853515625
# Epoch 517: Lower bound = -461.18280029296875
# Epoch 518: Lower bound = -459.8764343261719
# Epoch 519: Lower bound = -459.0889587402344
# Epoch 520: Lower bound = -468.0672607421875
# >> TEST
# >> Test rmse = 3.855470657348633, log_likelihood = -2.7422473430633545, r_squared = 0.8865394592285156
# Epoch 521: Lower bound = -458.308349609375
# Epoch 522: Lower bound = -458.129150390625
# Epoch 523: Lower bound = -457.76922607421875
# Epoch 524: Lower bound = -459.7040100097656
# Epoch 525: Lower bound = -461.0231018066406
# Epoch 526: Lower bound = -461.38653564453125
# Epoch 527: Lower bound = -463.1863098144531
# Epoch 528: Lower bound = -457.390380859375
# Epoch 529: Lower bound = -460.85772705078125
# Epoch 530: Lower bound = -459.4081115722656
# >> TEST
# >> Test rmse = 3.905851125717163, log_likelihood = -2.748591423034668, r_squared = 0.7356610298156738
# Epoch 531: Lower bound = -463.26983642578125
# Epoch 532: Lower bound = -464.90948486328125
# Epoch 533: Lower bound = -464.07147216796875
# Epoch 534: Lower bound = -457.7462158203125
# Epoch 535: Lower bound = -465.4082946777344
# Epoch 536: Lower bound = -461.40692138671875
# Epoch 537: Lower bound = -460.3412780761719
# Epoch 538: Lower bound = -462.979248046875
# Epoch 539: Lower bound = -469.6347351074219
# Epoch 540: Lower bound = -462.8653259277344
# >> TEST
# >> Test rmse = 3.927841901779175, log_likelihood = -2.764439105987549, r_squared = 0.6716165542602539
# Epoch 541: Lower bound = -459.7757873535156
# Epoch 542: Lower bound = -459.7341613769531
# Epoch 543: Lower bound = -461.35479736328125
# Epoch 544: Lower bound = -456.57598876953125
# Epoch 545: Lower bound = -462.619873046875
# Epoch 546: Lower bound = -459.5416564941406
# Epoch 547: Lower bound = -471.20355224609375
# Epoch 548: Lower bound = -459.4662780761719
# Epoch 549: Lower bound = -456.37969970703125
# Epoch 550: Lower bound = -460.52203369140625
# >> TEST
# >> Test rmse = 3.9335215091705322, log_likelihood = -2.7464849948883057, r_squared = 0.6552505493164062
# Epoch 551: Lower bound = -463.4789123535156
# Epoch 552: Lower bound = -459.77703857421875
# Epoch 553: Lower bound = -461.1216125488281
# Epoch 554: Lower bound = -458.1123962402344
# Epoch 555: Lower bound = -462.3494873046875
# Epoch 556: Lower bound = -463.0736999511719
# Epoch 557: Lower bound = -461.0570983886719
# Epoch 558: Lower bound = -465.7432861328125
# Epoch 559: Lower bound = -465.8818664550781
# Epoch 560: Lower bound = -456.5806579589844
# >> TEST
# >> Test rmse = 3.9065191745758057, log_likelihood = -2.742173910140991, r_squared = 0.7336997985839844
# Epoch 561: Lower bound = -460.64617919921875
# Epoch 562: Lower bound = -460.9289245605469
# Epoch 563: Lower bound = -463.59613037109375
# Epoch 564: Lower bound = -460.1845703125
# Epoch 565: Lower bound = -458.3545837402344
# Epoch 566: Lower bound = -460.6551818847656
# Epoch 567: Lower bound = -461.29425048828125
# Epoch 568: Lower bound = -463.07305908203125
# Epoch 569: Lower bound = -462.39093017578125
# Epoch 570: Lower bound = -461.38153076171875
# >> TEST
# >> Test rmse = 4.010079860687256, log_likelihood = -2.7629218101501465, r_squared = 0.4413771629333496
# Epoch 571: Lower bound = -463.9544982910156
# Epoch 572: Lower bound = -460.7702941894531
# Epoch 573: Lower bound = -458.720458984375
# Epoch 574: Lower bound = -468.6351013183594
# Epoch 575: Lower bound = -458.7746276855469
# Epoch 576: Lower bound = -454.98968505859375
# Epoch 577: Lower bound = -462.19110107421875
# Epoch 578: Lower bound = -458.72674560546875
# Epoch 579: Lower bound = -463.2655029296875
# Epoch 580: Lower bound = -473.5509948730469
# >> TEST
# >> Test rmse = 3.8598132133483887, log_likelihood = -2.7540464401245117, r_squared = 0.8733015060424805
# Epoch 581: Lower bound = -461.6065673828125
# Epoch 582: Lower bound = -466.6549377441406
# Epoch 583: Lower bound = -461.30816650390625
# Epoch 584: Lower bound = -460.4307556152344
# Epoch 585: Lower bound = -463.0942077636719
# Epoch 586: Lower bound = -464.4961242675781
# Epoch 587: Lower bound = -460.08831787109375
# Epoch 588: Lower bound = -459.0848388671875
# Epoch 589: Lower bound = -463.5626220703125
# Epoch 590: Lower bound = -459.3152160644531
# >> TEST
# >> Test rmse = 3.8129396438598633, log_likelihood = -2.7418160438537598, r_squared = 1.0185937881469727
# Epoch 591: Lower bound = -459.3729248046875
# Epoch 592: Lower bound = -462.66583251953125
# Epoch 593: Lower bound = -460.8326721191406
# Epoch 594: Lower bound = -464.99542236328125
# Epoch 595: Lower bound = -461.3978576660156
# Epoch 596: Lower bound = -459.75067138671875
# Epoch 597: Lower bound = -462.60418701171875
# Epoch 598: Lower bound = -469.15191650390625
# Epoch 599: Lower bound = -462.78973388671875
# Epoch 600: Lower bound = -464.18402099609375
# >> TEST
# >> Test rmse = 3.9636764526367188, log_likelihood = -2.7582831382751465, r_squared = 0.5695290565490723
# Epoch 601: Lower bound = -456.93206787109375
# Epoch 602: Lower bound = -465.48760986328125
# Epoch 603: Lower bound = -465.89788818359375
# Epoch 604: Lower bound = -464.9210205078125
# Epoch 605: Lower bound = -462.44647216796875
# Epoch 606: Lower bound = -458.3780212402344
# Epoch 607: Lower bound = -460.80230712890625
# Epoch 608: Lower bound = -459.1430969238281
# Epoch 609: Lower bound = -463.0759582519531
# Epoch 610: Lower bound = -459.24981689453125
# >> TEST
# >> Test rmse = 3.8811252117156982, log_likelihood = -2.753878355026245, r_squared = 0.8089747428894043
# Epoch 611: Lower bound = -462.1460266113281
# Epoch 612: Lower bound = -458.6920471191406
# Epoch 613: Lower bound = -461.9200439453125
# Epoch 614: Lower bound = -456.394775390625
# Epoch 615: Lower bound = -459.7913513183594
# Epoch 616: Lower bound = -458.9971618652344
# Epoch 617: Lower bound = -455.18084716796875
# Epoch 618: Lower bound = -460.6184997558594
# Epoch 619: Lower bound = -458.63409423828125
# Epoch 620: Lower bound = -461.1044006347656
# >> TEST
# >> Test rmse = 3.9425671100616455, log_likelihood = -2.7677254676818848, r_squared = 0.6293296813964844
# Epoch 621: Lower bound = -456.3687438964844
# Epoch 622: Lower bound = -459.32672119140625
# Epoch 623: Lower bound = -462.00665283203125
# Epoch 624: Lower bound = -461.8202209472656
# Epoch 625: Lower bound = -460.65155029296875
# Epoch 626: Lower bound = -462.9686584472656
# Epoch 627: Lower bound = -465.87078857421875
# Epoch 628: Lower bound = -458.186279296875
# Epoch 629: Lower bound = -457.6849060058594
# Epoch 630: Lower bound = -462.6283264160156
# >> TEST
# >> Test rmse = 3.83817720413208, log_likelihood = -2.7402172088623047, r_squared = 0.939704418182373
# Epoch 631: Lower bound = -461.0559997558594
# Epoch 632: Lower bound = -460.1015930175781
# Epoch 633: Lower bound = -461.0439453125
# Epoch 634: Lower bound = -462.2983703613281
# Epoch 635: Lower bound = -460.31524658203125
# Epoch 636: Lower bound = -462.3676452636719
# Epoch 637: Lower bound = -460.1716613769531
# Epoch 638: Lower bound = -472.7474060058594
# Epoch 639: Lower bound = -470.165771484375
# Epoch 640: Lower bound = -461.7754211425781
# >> TEST
# >> Test rmse = 3.9458744525909424, log_likelihood = -2.764138698577881, r_squared = 0.6198973655700684
# Epoch 641: Lower bound = -455.8970642089844
# Epoch 642: Lower bound = -464.42889404296875
# Epoch 643: Lower bound = -467.9331359863281
# Epoch 644: Lower bound = -468.7574157714844
# Epoch 645: Lower bound = -470.9913024902344
# Epoch 646: Lower bound = -461.1615295410156
# Epoch 647: Lower bound = -461.14190673828125
# Epoch 648: Lower bound = -459.50445556640625
# Epoch 649: Lower bound = -461.05255126953125
# Epoch 650: Lower bound = -462.5771789550781
# >> TEST
# >> Test rmse = 3.924903154373169, log_likelihood = -2.753784418106079, r_squared = 0.6801128387451172
# Epoch 651: Lower bound = -461.9089660644531
# Epoch 652: Lower bound = -458.5455627441406
# Epoch 653: Lower bound = -461.3284606933594
# Epoch 654: Lower bound = -464.59136962890625
# Epoch 655: Lower bound = -464.8027648925781
# Epoch 656: Lower bound = -460.884765625
# Epoch 657: Lower bound = -459.297119140625
# Epoch 658: Lower bound = -459.381591796875
# Epoch 659: Lower bound = -460.1348876953125
# Epoch 660: Lower bound = -458.84405517578125
# >> TEST
# >> Test rmse = 3.8694581985473633, log_likelihood = -2.7427895069122314, r_squared = 0.8440585136413574
# Epoch 661: Lower bound = -456.7845153808594
# Epoch 662: Lower bound = -459.2205810546875
# Epoch 663: Lower bound = -471.14910888671875
# Epoch 664: Lower bound = -460.8940124511719
# Epoch 665: Lower bound = -461.4933776855469
# Epoch 666: Lower bound = -459.8121032714844
# Epoch 667: Lower bound = -458.3574523925781
# Epoch 668: Lower bound = -458.56585693359375
# Epoch 669: Lower bound = -465.853759765625
# Epoch 670: Lower bound = -461.9878845214844
# >> TEST
# >> Test rmse = 3.9298479557037354, log_likelihood = -2.757854461669922, r_squared = 0.665827751159668
# Epoch 671: Lower bound = -460.8172607421875
# Epoch 672: Lower bound = -473.9072265625
# Epoch 673: Lower bound = -461.7718811035156
# Epoch 674: Lower bound = -463.14715576171875
# Epoch 675: Lower bound = -462.7915954589844
# Epoch 676: Lower bound = -462.8819274902344
# Epoch 677: Lower bound = -459.8077087402344
# Epoch 678: Lower bound = -458.98382568359375
# Epoch 679: Lower bound = -457.7779846191406
# Epoch 680: Lower bound = -458.7126770019531
# >> TEST
# >> Test rmse = 3.9158527851104736, log_likelihood = -2.748450756072998, r_squared = 0.7063989639282227
# Epoch 681: Lower bound = -462.8592529296875
# Epoch 682: Lower bound = -462.7592468261719
# Epoch 683: Lower bound = -472.5030212402344
# Epoch 684: Lower bound = -465.1572570800781
# Epoch 685: Lower bound = -456.1466064453125
# Epoch 686: Lower bound = -461.3515625
# Epoch 687: Lower bound = -459.0994873046875
# Epoch 688: Lower bound = -461.5257873535156
# Epoch 689: Lower bound = -460.21343994140625
# Epoch 690: Lower bound = -458.03436279296875
# >> TEST
# >> Test rmse = 3.8883135318756104, log_likelihood = -2.753849983215332, r_squared = 0.7875165939331055
# Epoch 691: Lower bound = -455.6665344238281
# Epoch 692: Lower bound = -469.7771301269531
# Epoch 693: Lower bound = -463.4135437011719
# Epoch 694: Lower bound = -460.6684265136719
# Epoch 695: Lower bound = -460.02093505859375
# Epoch 696: Lower bound = -460.91778564453125
# Epoch 697: Lower bound = -459.3193054199219
# Epoch 698: Lower bound = -461.5775451660156
# Epoch 699: Lower bound = -462.8689270019531
# Epoch 700: Lower bound = -459.6513366699219
# >> TEST
# >> Test rmse = 3.932711601257324, log_likelihood = -2.757923126220703, r_squared = 0.6575789451599121
# Epoch 701: Lower bound = -458.31475830078125
# Epoch 702: Lower bound = -464.7406311035156
# Epoch 703: Lower bound = -461.10089111328125
# Epoch 704: Lower bound = -458.36541748046875
# Epoch 705: Lower bound = -461.8470764160156
# Epoch 706: Lower bound = -458.8999938964844
# Epoch 707: Lower bound = -460.0421142578125
# Epoch 708: Lower bound = -465.60198974609375
# Epoch 709: Lower bound = -467.2804870605469
# Epoch 710: Lower bound = -461.2442321777344
# >> TEST
# >> Test rmse = 3.8974106311798096, log_likelihood = -2.7570061683654785, r_squared = 0.760530948638916
# Epoch 711: Lower bound = -458.4410705566406
# Epoch 712: Lower bound = -462.5697937011719
# Epoch 713: Lower bound = -460.96990966796875
# Epoch 714: Lower bound = -460.55938720703125
# Epoch 715: Lower bound = -457.6822814941406
# Epoch 716: Lower bound = -460.0561828613281
# Epoch 717: Lower bound = -461.1484680175781
# Epoch 718: Lower bound = -463.6127014160156
# Epoch 719: Lower bound = -458.63702392578125
# Epoch 720: Lower bound = -460.6261901855469
# >> TEST
# >> Test rmse = 3.954249382019043, log_likelihood = -2.762042760848999, r_squared = 0.5961170196533203
# Epoch 721: Lower bound = -464.78924560546875
# Epoch 722: Lower bound = -458.2798156738281
# Epoch 723: Lower bound = -455.78277587890625
# Epoch 724: Lower bound = -458.2284851074219
# Epoch 725: Lower bound = -459.25897216796875
# Epoch 726: Lower bound = -457.403076171875
# Epoch 727: Lower bound = -462.5517272949219
# Epoch 728: Lower bound = -459.8567810058594
# Epoch 729: Lower bound = -460.2256164550781
# Epoch 730: Lower bound = -457.9535827636719
# >> TEST
# >> Test rmse = 3.8964438438415527, log_likelihood = -2.744447708129883, r_squared = 0.7633895874023438
# Epoch 731: Lower bound = -459.5033874511719
# Epoch 732: Lower bound = -463.4995422363281
# Epoch 733: Lower bound = -464.7863464355469
# Epoch 734: Lower bound = -465.8554382324219
# Epoch 735: Lower bound = -460.67523193359375
# Epoch 736: Lower bound = -461.4127502441406
# Epoch 737: Lower bound = -458.8741149902344
# Epoch 738: Lower bound = -465.1227111816406
# Epoch 739: Lower bound = -461.806396484375
# Epoch 740: Lower bound = -459.66644287109375
# >> TEST
# >> Test rmse = 3.850789785385132, log_likelihood = -2.7439517974853516, r_squared = 0.9008593559265137
# Epoch 741: Lower bound = -460.0365295410156
# Epoch 742: Lower bound = -456.98992919921875
# Epoch 743: Lower bound = -459.9307861328125
# Epoch 744: Lower bound = -460.69671630859375
# Epoch 745: Lower bound = -464.4455261230469
# Epoch 746: Lower bound = -463.5025329589844
# Epoch 747: Lower bound = -458.8150329589844
# Epoch 748: Lower bound = -462.4783020019531
# Epoch 749: Lower bound = -461.1524353027344
# Epoch 750: Lower bound = -461.6094970703125
# >> TEST
# >> Test rmse = 3.9002490043640137, log_likelihood = -2.7463226318359375, r_squared = 0.7521500587463379
# Epoch 751: Lower bound = -464.02301025390625
# Epoch 752: Lower bound = -457.1499328613281
# Epoch 753: Lower bound = -464.5238952636719
# Epoch 754: Lower bound = -459.9604187011719
# Epoch 755: Lower bound = -460.2840881347656
# Epoch 756: Lower bound = -459.543701171875
# Epoch 757: Lower bound = -459.4972839355469
# Epoch 758: Lower bound = -460.6777648925781
# Epoch 759: Lower bound = -458.3963928222656
# Epoch 760: Lower bound = -455.2909851074219
# >> TEST
# >> Test rmse = 3.968001127243042, log_likelihood = -2.758011817932129, r_squared = 0.5573954582214355
# Epoch 761: Lower bound = -465.9977111816406
# Epoch 762: Lower bound = -462.7370910644531
# Epoch 763: Lower bound = -470.27972412109375
# Epoch 764: Lower bound = -459.74761962890625
# Epoch 765: Lower bound = -463.8369140625
# Epoch 766: Lower bound = -459.43963623046875
# Epoch 767: Lower bound = -463.1894226074219
# Epoch 768: Lower bound = -457.7895812988281
# Epoch 769: Lower bound = -464.3377990722656
# Epoch 770: Lower bound = -469.78570556640625
# >> TEST
# >> Test rmse = 3.958709478378296, log_likelihood = -2.744400978088379, r_squared = 0.5835142135620117
# Epoch 771: Lower bound = -458.5068054199219
# Epoch 772: Lower bound = -462.935546875
# Epoch 773: Lower bound = -458.9756774902344
# Epoch 774: Lower bound = -463.2861022949219
# Epoch 775: Lower bound = -467.11846923828125
# Epoch 776: Lower bound = -459.4239501953125
# Epoch 777: Lower bound = -464.568603515625
# Epoch 778: Lower bound = -474.1802673339844
# Epoch 779: Lower bound = -460.796630859375
# Epoch 780: Lower bound = -463.3454895019531
# >> TEST
# >> Test rmse = 3.870861768722534, log_likelihood = -2.7543914318084717, r_squared = 0.8398208618164062
# Epoch 781: Lower bound = -458.04083251953125
# Epoch 782: Lower bound = -462.072998046875
# Epoch 783: Lower bound = -457.83245849609375
# Epoch 784: Lower bound = -461.2870788574219
# Epoch 785: Lower bound = -462.3749694824219
# Epoch 786: Lower bound = -468.97576904296875
# Epoch 787: Lower bound = -463.650146484375
# Epoch 788: Lower bound = -463.2735595703125
# Epoch 789: Lower bound = -465.0580139160156
# Epoch 790: Lower bound = -457.9220886230469
# >> TEST
# >> Test rmse = 3.9175820350646973, log_likelihood = -2.752546548843384, r_squared = 0.7013626098632812
# Epoch 791: Lower bound = -458.84124755859375
# Epoch 792: Lower bound = -456.5682373046875
# Epoch 793: Lower bound = -464.7955627441406
# Epoch 794: Lower bound = -460.1524353027344
# Epoch 795: Lower bound = -459.0466613769531
# Epoch 796: Lower bound = -460.4794616699219
# Epoch 797: Lower bound = -458.2979431152344
# Epoch 798: Lower bound = -463.00811767578125
# Epoch 799: Lower bound = -456.6340026855469
# Epoch 800: Lower bound = -458.02105712890625
# >> TEST
# >> Test rmse = 3.94132661819458, log_likelihood = -2.7523603439331055, r_squared = 0.63287353515625
# Epoch 801: Lower bound = -461.67816162109375
# Epoch 802: Lower bound = -459.532958984375
# Epoch 803: Lower bound = -460.84710693359375
# Epoch 804: Lower bound = -459.0105285644531
# Epoch 805: Lower bound = -464.4285888671875
# Epoch 806: Lower bound = -460.4945373535156
# Epoch 807: Lower bound = -458.2874450683594
# Epoch 808: Lower bound = -464.1781921386719
# Epoch 809: Lower bound = -459.2303466796875
# Epoch 810: Lower bound = -459.12335205078125
# >> TEST
# >> Test rmse = 3.9244649410247803, log_likelihood = -2.759215831756592, r_squared = 0.6813807487487793
# Epoch 811: Lower bound = -460.8707580566406
# Epoch 812: Lower bound = -469.002197265625
# Epoch 813: Lower bound = -459.91717529296875
# Epoch 814: Lower bound = -458.748779296875
# Epoch 815: Lower bound = -456.053955078125
# Epoch 816: Lower bound = -461.2347106933594
# Epoch 817: Lower bound = -474.6532287597656
# Epoch 818: Lower bound = -459.8070373535156
# Epoch 819: Lower bound = -458.5574951171875
# Epoch 820: Lower bound = -467.4570007324219
# >> TEST
# >> Test rmse = 3.847158193588257, log_likelihood = -2.741145133972168, r_squared = 0.9120049476623535
# Epoch 821: Lower bound = -458.9102783203125
# Epoch 822: Lower bound = -456.999267578125
# Epoch 823: Lower bound = -459.98590087890625
# Epoch 824: Lower bound = -459.3316955566406
# Epoch 825: Lower bound = -456.140380859375
# Epoch 826: Lower bound = -456.99676513671875
# Epoch 827: Lower bound = -467.3657531738281
# Epoch 828: Lower bound = -462.3524475097656
# Epoch 829: Lower bound = -461.4141540527344
# Epoch 830: Lower bound = -456.1466979980469
# >> TEST
# >> Test rmse = 3.8844692707061768, log_likelihood = -2.7443594932556152, r_squared = 0.798978328704834
# Epoch 831: Lower bound = -460.53765869140625
# Epoch 832: Lower bound = -462.8072204589844
# Epoch 833: Lower bound = -459.9452819824219
# Epoch 834: Lower bound = -460.2959899902344
# Epoch 835: Lower bound = -459.9681091308594
# Epoch 836: Lower bound = -467.22210693359375
# Epoch 837: Lower bound = -460.47576904296875
# Epoch 838: Lower bound = -472.9524841308594
# Epoch 839: Lower bound = -459.4673767089844
# Epoch 840: Lower bound = -460.2713623046875
# >> TEST
# >> Test rmse = 3.906444549560547, log_likelihood = -2.755521535873413, r_squared = 0.7339181900024414
# Epoch 841: Lower bound = -458.2881164550781
# Epoch 842: Lower bound = -456.94921875
# Epoch 843: Lower bound = -465.1084899902344
# Epoch 844: Lower bound = -458.5395202636719
# Epoch 845: Lower bound = -466.6062316894531
# Epoch 846: Lower bound = -463.658447265625
# Epoch 847: Lower bound = -466.52520751953125
# Epoch 848: Lower bound = -465.1649169921875
# Epoch 849: Lower bound = -457.52557373046875
# Epoch 850: Lower bound = -462.2609558105469
# >> TEST
# >> Test rmse = 3.920274019241333, log_likelihood = -2.7512834072113037, r_squared = 0.693535327911377
# Epoch 851: Lower bound = -456.03399658203125
# Epoch 852: Lower bound = -459.328857421875
# Epoch 853: Lower bound = -466.3485412597656
# Epoch 854: Lower bound = -460.62042236328125
# Epoch 855: Lower bound = -460.8785705566406
# Epoch 856: Lower bound = -465.8713073730469
# Epoch 857: Lower bound = -463.4364013671875
# Epoch 858: Lower bound = -461.6430969238281
# Epoch 859: Lower bound = -462.8150329589844
# Epoch 860: Lower bound = -458.4358825683594
# >> TEST
# >> Test rmse = 3.8607730865478516, log_likelihood = -2.7403345108032227, r_squared = 0.8703804016113281
# Epoch 861: Lower bound = -460.42657470703125
# Epoch 862: Lower bound = -460.4870910644531
# Epoch 863: Lower bound = -461.33868408203125
# Epoch 864: Lower bound = -462.1459045410156
# Epoch 865: Lower bound = -465.2725830078125
# Epoch 866: Lower bound = -460.8963623046875
# Epoch 867: Lower bound = -459.7076721191406
# Epoch 868: Lower bound = -464.3856201171875
# Epoch 869: Lower bound = -459.1230163574219
# Epoch 870: Lower bound = -460.5398254394531
# >> TEST
# >> Test rmse = 3.93917179107666, log_likelihood = -2.7590200901031494, r_squared = 0.6390380859375
# Epoch 871: Lower bound = -458.3677062988281
# Epoch 872: Lower bound = -458.73846435546875
# Epoch 873: Lower bound = -465.3539733886719
# Epoch 874: Lower bound = -463.75909423828125
# Epoch 875: Lower bound = -466.6078186035156
# Epoch 876: Lower bound = -462.2093200683594
# Epoch 877: Lower bound = -464.8397521972656
# Epoch 878: Lower bound = -462.407958984375
# Epoch 879: Lower bound = -459.5531921386719
# Epoch 880: Lower bound = -455.1629638671875
# >> TEST
# >> Test rmse = 3.917555093765259, log_likelihood = -2.748595952987671, r_squared = 0.701441764831543
# Epoch 881: Lower bound = -461.1727600097656
# Epoch 882: Lower bound = -458.6957092285156
# Epoch 883: Lower bound = -459.6554870605469
# Epoch 884: Lower bound = -462.487548828125
# Epoch 885: Lower bound = -457.5318908691406
# Epoch 886: Lower bound = -454.6274719238281
# Epoch 887: Lower bound = -464.19195556640625
# Epoch 888: Lower bound = -462.89874267578125
# Epoch 889: Lower bound = -460.3133544921875
# Epoch 890: Lower bound = -464.08343505859375
# >> TEST
# >> Test rmse = 3.881465435028076, log_likelihood = -2.739084482192993, r_squared = 0.807957649230957
# Epoch 891: Lower bound = -465.520751953125
# Epoch 892: Lower bound = -464.4068908691406
# Epoch 893: Lower bound = -462.9688415527344
# Epoch 894: Lower bound = -459.6605529785156
# Epoch 895: Lower bound = -461.37542724609375
# Epoch 896: Lower bound = -461.754150390625
# Epoch 897: Lower bound = -462.9823303222656
# Epoch 898: Lower bound = -458.3606872558594
# Epoch 899: Lower bound = -461.4613952636719
# Epoch 900: Lower bound = -459.74957275390625
# >> TEST
# >> Test rmse = 3.972175121307373, log_likelihood = -2.7628049850463867, r_squared = 0.5457220077514648
# Epoch 901: Lower bound = -463.01104736328125
# Epoch 902: Lower bound = -459.3243103027344
# Epoch 903: Lower bound = -461.73480224609375
# Epoch 904: Lower bound = -475.8370361328125
# Epoch 905: Lower bound = -461.6139221191406
# Epoch 906: Lower bound = -459.6496276855469
# Epoch 907: Lower bound = -464.7253723144531
# Epoch 908: Lower bound = -459.56207275390625
# Epoch 909: Lower bound = -475.50115966796875
# Epoch 910: Lower bound = -457.984619140625
# >> TEST
# >> Test rmse = 3.878934144973755, log_likelihood = -2.7525711059570312, r_squared = 0.8155398368835449
# Epoch 911: Lower bound = -458.2138977050781
# Epoch 912: Lower bound = -466.52789306640625
# Epoch 913: Lower bound = -461.380126953125
# Epoch 914: Lower bound = -469.5823669433594
# Epoch 915: Lower bound = -458.5868835449219
# Epoch 916: Lower bound = -457.6912841796875
# Epoch 917: Lower bound = -458.6947937011719
# Epoch 918: Lower bound = -460.9873046875
# Epoch 919: Lower bound = -465.95184326171875
# Epoch 920: Lower bound = -456.8309631347656
# >> TEST
# >> Test rmse = 3.935166597366333, log_likelihood = -2.7574236392974854, r_squared = 0.6505231857299805
# Epoch 921: Lower bound = -465.0318298339844
# Epoch 922: Lower bound = -460.4530334472656
# Epoch 923: Lower bound = -464.0093688964844
# Epoch 924: Lower bound = -465.7001953125
# Epoch 925: Lower bound = -460.7249450683594
# Epoch 926: Lower bound = -463.1001892089844
# Epoch 927: Lower bound = -467.98651123046875
# Epoch 928: Lower bound = -465.6346740722656
# Epoch 929: Lower bound = -460.5566101074219
# Epoch 930: Lower bound = -466.1405944824219
# >> TEST
# >> Test rmse = 4.010155200958252, log_likelihood = -2.7637271881103516, r_squared = 0.44117307662963867
# Epoch 931: Lower bound = -459.0597839355469
# Epoch 932: Lower bound = -460.523193359375
# Epoch 933: Lower bound = -462.03265380859375
# Epoch 934: Lower bound = -457.03070068359375
# Epoch 935: Lower bound = -462.7450866699219
# Epoch 936: Lower bound = -467.1024169921875
# Epoch 937: Lower bound = -460.7556457519531
# Epoch 938: Lower bound = -460.1944580078125
# Epoch 939: Lower bound = -459.7725830078125
# Epoch 940: Lower bound = -473.3369140625
# >> TEST
# >> Test rmse = 3.9871816635131836, log_likelihood = -2.7587203979492188, r_squared = 0.5040555000305176
# Epoch 941: Lower bound = -471.6069030761719
# Epoch 942: Lower bound = -468.275390625
# Epoch 943: Lower bound = -457.8187561035156
# Epoch 944: Lower bound = -458.30987548828125
# Epoch 945: Lower bound = -467.1315002441406
# Epoch 946: Lower bound = -460.8910827636719
# Epoch 947: Lower bound = -459.0691223144531
# Epoch 948: Lower bound = -461.3624267578125
# Epoch 949: Lower bound = -460.95721435546875
# Epoch 950: Lower bound = -468.1827087402344
# >> TEST
# >> Test rmse = 3.9333152770996094, log_likelihood = -2.763735771179199, r_squared = 0.6558437347412109
# Epoch 951: Lower bound = -461.1238098144531
# Epoch 952: Lower bound = -463.0532531738281
# Epoch 953: Lower bound = -458.49761962890625
# Epoch 954: Lower bound = -463.4484558105469
# Epoch 955: Lower bound = -456.220947265625
# Epoch 956: Lower bound = -459.2051696777344
# Epoch 957: Lower bound = -457.85235595703125
# Epoch 958: Lower bound = -460.10821533203125
# Epoch 959: Lower bound = -470.146484375
# Epoch 960: Lower bound = -470.78125
# >> TEST
# >> Test rmse = 3.83781099319458, log_likelihood = -2.7543728351593018, r_squared = 0.9408373832702637
# Epoch 961: Lower bound = -459.7000732421875
# Epoch 962: Lower bound = -461.785888671875
# Epoch 963: Lower bound = -461.489990234375
# Epoch 964: Lower bound = -456.59375
# Epoch 965: Lower bound = -461.6085205078125
# Epoch 966: Lower bound = -461.1067810058594
# Epoch 967: Lower bound = -459.58050537109375
# Epoch 968: Lower bound = -458.42205810546875
# Epoch 969: Lower bound = -467.77813720703125
# Epoch 970: Lower bound = -463.26544189453125
# >> TEST
# >> Test rmse = 3.8432884216308594, log_likelihood = -2.75315523147583, r_squared = 0.9239168167114258
# Epoch 971: Lower bound = -460.9034423828125
# Epoch 972: Lower bound = -461.1601257324219
# Epoch 973: Lower bound = -464.0613098144531
# Epoch 974: Lower bound = -473.4432678222656
# Epoch 975: Lower bound = -468.8904113769531
# Epoch 976: Lower bound = -466.03961181640625
# Epoch 977: Lower bound = -460.2062683105469
# Epoch 978: Lower bound = -460.18597412109375
# Epoch 979: Lower bound = -456.7421569824219
# Epoch 980: Lower bound = -458.82366943359375
# >> TEST
# >> Test rmse = 3.871596574783325, log_likelihood = -2.7415456771850586, r_squared = 0.8376049995422363
# Epoch 981: Lower bound = -457.0410461425781
# Epoch 982: Lower bound = -460.51776123046875
# Epoch 983: Lower bound = -458.7803955078125
# Epoch 984: Lower bound = -469.8959655761719
# Epoch 985: Lower bound = -457.58819580078125
# Epoch 986: Lower bound = -458.1622314453125
# Epoch 987: Lower bound = -458.7059631347656
# Epoch 988: Lower bound = -457.20428466796875
# Epoch 989: Lower bound = -459.1427917480469
# Epoch 990: Lower bound = -469.8872375488281
# >> TEST
# >> Test rmse = 3.907911539077759, log_likelihood = -2.75130558013916, r_squared = 0.7296147346496582
# Epoch 991: Lower bound = -459.1781311035156
# Epoch 992: Lower bound = -458.6769714355469
# Epoch 993: Lower bound = -461.8909606933594
# Epoch 994: Lower bound = -463.6572570800781
# Epoch 995: Lower bound = -460.2031555175781
# Epoch 996: Lower bound = -457.1731872558594
# Epoch 997: Lower bound = -459.2273254394531
# Epoch 998: Lower bound = -458.0313415527344
# Epoch 999: Lower bound = -478.46636962890625
# Epoch 1000: Lower bound = -457.8863830566406
# >> TEST
# >> Test rmse = 3.887535810470581, log_likelihood = -2.7646427154541016, r_squared = 0.7898330688476562
